# %%
import hiddenlayer as h
import torchvision
import torch
import os
import tensorwatch as tw
from visdom import Visdom

# %%
name_env = 'testouille'
viz = Visdom(os.environ['VISDOM_SERVER'],
                  env=name_env,
                  username=os.environ['VISDOM_USER'],
                  password=os.environ['VISDOM_PASS'])
# Out:
# WARNING:root:Setting up a new session...

# %%
model = torchvision.models.vgg16(pretrained=False)

# %%
h.build_graph(model,torch.zeros(1,3,224,224))

# %%
gr = tw.draw_model(model)

# %%
type(gr)
# Out:
# tensorwatch.model_graph.hiddenlayer.graph.Graph
# ERROR:visdom:[Errno 110] Connection timed out
# ERROR:visdom:[Errno -2] Name or service not known
# ERROR:visdom:[Errno -2] Name or service not known
# ERROR:visdom:[Errno -2] Name or service not known
# ERROR:visdom:[Errno -2] Name or service not known
# ERROR:visdom:[Errno -2] Name or service not known
# ERROR:visdom:[Errno -2] Name or service not known
# ERROR:visdom:[Errno -2] Name or service not known
